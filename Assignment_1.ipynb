# %% [markdown]
# # ASSIGNMENT-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.READING THE DATASET

# %%
data=pd.read_excel('iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2.DISPLAYING THE COLUMNS

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### 3.FINDING THE MEAN OF THE COLUMNS

# %%
np.mean(data)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4.CHECKING FOR NULL VALUES IN THE DATASET

# %%
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 5.VISUALIZATIONS

# %% [markdown]
# ### a.Histogram

# %%
data[['SL','PL']].plot.hist(rwidth=0.9)
plt.title('Distrubution of length of Iris plants')
plt.xlabel('Sepal & Petal Length')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0., 10., 20., 30., 40., 50.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data[['SW','PW']].plot.hist(rwidth=0.9)
plt.title('Distribution of Width of Iris plants')
plt.xlabel('Sepal & Petal Width')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60., 70., 80.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### b.Scatter Plot

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
plt.scatter(data['SL'],data['PL'],s=9,c='red')
plt.title('Sepal length V/S Petal length')
plt.xlabel('Sepal length')
plt.ylabel('Petal length')

plt.subplot(2,1,2)
plt.scatter(data['SW'],data['PW'],s=10,c='blue')
plt.title('Sepal Width V/S Petal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')

plt.tight_layout()

# %% [markdown]
# ### c.Pair Plots

# %%
slice_data=data[['SW','SL','PL','PW']]

# %%
sns.pairplot(slice_data)

# %% [markdown]
# ### d.Boxplots

# %%
sns.boxplot(x='Classification',y='SL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.boxplot(x='Classification',y='PL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.boxplot(x='Classification',y='SW',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %%
sns.boxplot(x='Classification',y='PW',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>

# %% [markdown]
# ### e.Swarm Plots

# %%
sns.swarmplot(x='Classification',y='SL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.swarmplot(x='Classification',y='PL',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.swarmplot(x='Classification',y='SW',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %%
sns.swarmplot(x='Classification',y='PW',data=data)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>

# %% [markdown]
# # END
